# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
df = pd.read_csv('testcsv.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                           abstract       date  doctype                                           headline                        id  news_desk                                          paragraph  section  subsection                                               text     type
# 0           0  Clearing of site for Health Center and office ...   1/3/1960  article  Harvard Ready to Clear the Site For University...  4fc4076f45c1498b0d8bc377        NaN  CAMBRIDGE, Mass., Jan. 2 -- Clearing of the si...      NaN         NaN  Harvard Ready to Clear the Site For University...  Article
# 1           1                                                NaN   1/2/1960  article           Play Tuesday to Aid Judson Health Center  4fc4076945c1498b0d8bb91d        NaN                                                NaN      NaN         NaN       Play Tuesday to Aid Judson Health Center      Article
# 2           2  Comr Baumgartner repts NYC will aid basic rese...   1/6/1960  article  Narcotic Addiction To Be Researched By City He...  4fc408b545c1498b0d8c2c58        NaN  Plans for a new program of city-supported basi...      NaN         NaN  Narcotic Addiction To Be Researched By City He...  Article
# 3           3                                     Oberwager, Jno   1/3/1960  article             DR. JOHN OBERWAGER, CITY HEALTH EXPERT  4fc4068445c1498b0d8b7fe0        NaN                                                NaN      NaN         NaN  DR. JOHN OBERWAGER, CITY HEALTH EXPERT   Oberw...  Article
# 4           4  US Defense Dept to spend $1 million for tranqu...  1/10/1960  article       Cost of Tranquilizers For Military a Million  4fc407d945c1498b0d8be692        NaN                                                NaN      NaN         NaN  Cost of Tranquilizers For Military a Million  ...  Article

# %%
import nltk
from nltk.tokenize import TreebankWordTokenizer #token
from nltk.corpus import stopwords #stopwords
from nltk.stem import WordNetLemmatizer #lemma

# %%
nltk.download()
# Out:
# showing info http://www.nltk.org/nltk_data/
# True

# %%
stops = stopwords.words('english')
stops.append(u'health')
punctuation = list('.,;:!?()[]{}`''\"@#$^&*+-|=~_')

# %%
wnl = WordNetLemmatizer()

# %%
def get_parts(thetext):
    nouns=[]
    tokens = TreebankWordTokenizer().tokenize(thetext)
    tagged = nltk.pos_tag(tokens) # a list of tuples
    for tup in tagged : 
        w, tag = tup  
        print w, tag
        if tag in ['NN', 'NNS', 'NNP', 'NNPS']:
            word = wnl.lemmatize(w.lower())
            print word
            if word[-1] in punctuation : 
                word = word[:-1]
            if word in stops or word in punctuation or len(word)==1 :
                continue
            nouns.append(word)
    nouns2=[]
    for n in nouns:
        if len(n)!=0:
            nouns2.append(n)
    return nouns2

# %%
parseout = []
for index, row in df.iterrows() : 
    parseout.append(get_parts(row.text))
# Out:
# Harvard NNP
# harvard
# Ready NNP
# ready
# to TO
# Clear VB
# the DT
# Site NNP
# site
# For IN
# University NNP
# university
# Health NNP
# health
# Center NNP
# center
# CAMBRIDGE NNP
# cambridge
# , ,
# Mass. NNP
# mass.
# , ,
# Jan. NNP
# jan.
# 2 CD
# -- :
# Clearing NN
# clearing
# of IN
# the DT
# site NN
# site
# for IN
# a DT
# tenstory JJ
# University NNP
# university
# Health NNP
# health
# Center NNP
# center
# and CC
# office NN
# office
# building NN
# building
# for IN
# Harvard NNP
# harvard
# University NNP
# university
# will MD
# begin VB
# early RB
# this DT
# month. NN
# month.
# Clearing NNP
# clearing
# of IN
# site NN
# site
# for IN
# Health NNP
# health
# Center NNP
# center
# and CC
# office NN
# office
# bldg NN
# bldg
# set VBN
# ; :
# model NN
# model
# illus NN
# illus
# Play NN
# play
# Tuesday NNP
# tuesday
# to TO
# Aid NNP
# aid
# Judson NNP
# judson
# Health NNP
# health
# Center NNP
# center
# Narcotic JJ
# Addiction NNP
# addiction
# To TO
# Be VB
# Researched VBN
# By IN
# City NNP
# city
# Health NNP
# health
# Unit NNP
# unit
# Plans VBZ
# for IN
# a DT
# new JJ
# program NN
# program
# of IN
# city-supported JJ
# basic JJ
# research NN
# research
# into IN
# narcotics NNS
# narcotic
# addiction NN
# addiction
# and CC
# other JJ
# health NN
# health
# problems NNS
# problem
# were VBD
# outlined VBN
# to TO
# a DT
# City NNP
# city
# Council NNP
# council
# committee NN
# committee
# yesterday NN
# yesterday
# by IN
# Dr. NNP
# dr.
# Leona NNP
# leona
# Baumgartner NNP
# baumgartner
# , ,
# Commissioner NNP
# commissioner
# of IN
# Health. NNP
# health.
# Comr NNP
# comr
# Baumgartner NNP
# baumgartner
# repts VBZ
# NYC NNP
# nyc
# will MD
# aid VB
# basic JJ
# research NN
# research
# on IN
# addiction NN
# addiction
# DR. NNP
# dr.
# JOHN NNP
# john
# OBERWAGER NNP
# oberwager
# , ,
# CITY NNP
# city
# HEALTH NNP
# health
# EXPERT NNP
# expert
# Oberwager NNP
# oberwager
# , ,
# Jno NNP
# jno
# Cost NN
# cost
# of IN
# Tranquilizers NNP
# tranquilizer
# For IN
# Military NNP
# military
# a DT
# Million NNP
# million
# US NNP
# u
# Defense NNP
# defense
# Dept NNP
# dept
# to TO
# spend VB
# $ $
# 1 CD
# million CD
# for IN
# tranquilizing VBG
# drugs NNS
# drug
# , ,
# fiscal JJ
# '61 CD
# SUBURBAN NNP
# suburban
# FATHERS NNP
# father
# GET NNP
# get
# PANEL NNP
# panel
# 'S POS
# ADVICE NNP
# advice
# HARTSDALE NNP
# hartsdale
# , ,
# N.Y. NNP
# n.y.
# , ,
# Jan. NNP
# jan.
# 2 CD
# -- :
# Panelists NNS
# panelist
# on IN
# a DT
# radio NN
# radio
# broadcast NN
# broadcast
# , ,
# `` ``
# Life NNP
# life
# in IN
# Suburbia NNP
# suburbia
# , ,
# '' ''
# agreed VBD
# tonight NN
# tonight
# that IN
# it PRP
# was VBD
# n't RB
# the DT
# amount NN
# amount
# of IN
# time NN
# time
# fathers NNS
# father
# spent VBD
# at IN
# home NN
# home
# but CC
# the DT
# way NN
# way
# they PRP
# spent VBD
# it PRP
# that WDT
# was VBD
# important JJ
# in IN
# creating VBG
# a DT
# happy JJ
# home. NN
# home.
# Westchester NNP
# westchester
# County NNP
# county
# Mental NNP
# mental
# Health NNP
# health
# Assn NNP
# assn
# radio NN
# radio
# series NN
# series
# begins VBZ
# Birth NNP
# birth
# Defects NNP
# defect
# Center NNP
# center
# Ready NNP
# ready
# Children NNP
# child
# 's POS
# Hosp NNP
# hosp
# , ,
# Columbus NNP
# columbus
# , ,
# Ohio NNP
# ohio
# , ,
# to TO
# dedicate VB
# center NN
# center
# for IN
# study NN
# study
# of IN
# birth NN
# birth
# defects NNS
# defect
# , ,
# 1st CD
# in IN
# US NNP
# u
# ; :
# center NN
# center
# financed VBN
# by IN
# Natl NNP
# natl
# Foundation NNP
# foundation
# grant NN
# grant
# Cost NN
# cost
# of IN
# Medicines NNP
# medicine
# The DT
# cost NN
# cost
# of IN
# medicines NNS
# medicine
# comes VBZ
# close RB
# home NN
# home
# to TO
# almost RB
# every DT
# one CD
# of IN
# us PRP
# , ,
# especially RB
# when WRB
# we PRP
# think VBP
# they PRP
# are VBP
# too RB
# high. JJ
# Senator NNP
# senator
# Kefauver NNP
# kefauver
# 's POS
# investigations NNS
# investigation
# have VBP
# revealed VBN
# how WRB
# wide JJ
# is VBZ
# the DT
# public JJ
# interest NN
# interest
# in IN
# the DT
# subject NN
# subject
# , ,
# and CC
# have VBP
# stirred VBN
# up RP
# even RB
# more JJR
# concern. JJ
# ed NN
# ed
# on IN
# high JJ
# costs NNS
# cost
# cites VBZ
# Health NNP
# health
# , ,
# Educ NNP
# educ
# and CC
# Welfare NNP
# welfare
# Dept NNP
# dept
# rept VBD
# that IN
# '58 CD
# spending NN
# spending
# for IN
# drugs NNS
# drug
# and CC
# appliances NNS
# appliance
# ( (
# $ $
# 4.4 CD
# billion CD
# ) )
# was VBD
# higher JJR
# than IN
# for IN
# drs NN
# drs
# fees NNS
# fee
# ( (
# $ $
# 4.3 CD
# billion CD
# ) )
# ; :
# suggests VBZ
# possibility NN
# possibility
# of IN
# prepayment NN
# prepayment
# plan NN
# plan
# Children NNP
# child
# Drinking NNP
# drinking
# More JJR
# Milk NNP
# milk
# Agr NNP
# agr
# Dept NNP
# dept
# repts VBZ
# milk NN
# milk
# consumption NN
# consumption
# rise NN
# rise
# from IN
# special JJ
# milk NN
# milk
# program NN
# program
# CITY NNP
# city
# TEACHES NNP
# teach
# PUPILS NNP
# pupil
# TO NNP
# to
# SHUN NNP
# shun
# CIGARETTES NNP
# cigarette
# Dr. NNP
# dr.
# Leona NNP
# leona
# Baumgartner NNP
# baumgartner
# , ,
# the DT
# city NN
# city
# 's POS
# Health NNP
# health
# Commissioner NNP
# commissioner
# , ,
# said VBD
# in IN
# a DT
# television NN
# television
# interview NN
# interview
# last JJ
# night NN
# night
# that IN
# her PRP$
# department NN
# department
# was VBD
# cooperating VBG
# with IN
# the DT
# schools NNS
# school
# in IN
# an DT
# attempt NN
# attempt
# to TO
# persuade VB
# pupils NNS
# pupil
# never RB
# to TO
# start VB
# smoking. VB
# Comr NNP
# comr
# Baumgartner NNP
# baumgartner
# on IN
# Health NNP
# health
# Dept NNP
# dept
# program NN
# program
# to TO
# persuade VB
# pupils NNS
# pupil
# not RB
# to TO
# start VB
# smoking NN
# smoking

# %%
parseout[:10]
# Out:
# [['harvard',
#   'ready',
#   'site',
#   'university',
#   'center',
#   'cambridge',
#   'mass',
#   'jan',
#   'clearing',
#   'site',
#   'university',
#   'center',
#   'office',
#   'building',
#   'harvard',
#   'university',
#   'month',
#   'clearing',
#   'site',
#   'center',
#   'office',
#   'bldg',
#   'model',
#   'illus'],
#  ['play', 'tuesday', 'aid', 'judson', 'center'],
#  ['addiction',
#   'city',
#   'unit',
#   'program',
#   'research',
#   u'narcotic',
#   'addiction',
#   u'problem',
#   'city',
#   'council',
#   'committee',
#   'yesterday',
#   'dr',
#   'leona',
#   'baumgartner',
#   'commissioner',
#   'comr',
#   'baumgartner',
#   'nyc',
#   'research',
#   'addiction'],
#  ['dr', 'john', 'oberwager', 'city', 'expert', 'oberwager', 'jno'],
#  ['cost', u'tranquilizer', 'military', 'million', 'defense', 'dept', u'drug'],
#  ['suburban',
#   u'father',
#   'get',
#   'panel',
#   'advice',
#   'hartsdale',
#   'n.y',
#   'jan',
#   u'panelist',
#   'radio',
#   'broadcast',
#   'life',
#   'suburbia',
#   'tonight',
#   'amount',
#   'time',
#   u'father',
#   'home',
#   'way',
#   'home',
#   'westchester',
#   'county',
#   'mental',
#   'assn',
#   'radio',
#   'series'],
#  ['birth',
#   u'defect',
#   'center',
#   'ready',
#   u'child',
#   'hosp',
#   'columbus',
#   'ohio',
#   'center',
#   'study',
#   'birth',
#   u'defect',
#   'center',
#   'natl',
#   'foundation',
#   'grant'],
#  ['cost',
#   u'medicine',
#   'cost',
#   u'medicine',
#   'home',
#   'senator',
#   'kefauver',
#   u'investigation',
#   'interest',
#   'subject',
#   'ed',
#   u'cost',
#   'educ',
#   'welfare',
#   'dept',
#   'spending',
#   u'drug',
#   u'appliance',
#   'drs',
#   u'fee',
#   'possibility',
#   'prepayment',
#   'plan'],
#  [u'child',
#   'drinking',
#   'milk',
#   'agr',
#   'dept',
#   'milk',
#   'consumption',
#   'rise',
#   'milk',
#   'program'],
#  ['city',
#   u'teach',
#   u'pupil',
#   'shun',
#   u'cigarette',
#   'dr',
#   'leona',
#   'baumgartner',
#   'city',
#   'commissioner',
#   'television',
#   'interview',
#   'night',
#   'department',
#   u'school',
#   'attempt',
#   u'pupil',
#   'comr',
#   'baumgartner',
#   'dept',
#   'program',
#   u'pupil',
#   'smoking']]
