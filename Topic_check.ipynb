# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
import heapq

# %%
comb1966 = pd.read_csv("/Users/Luke/Documents/cs109/project/comb1966.csv")

# %%
comb1966.head()
# Out:
#    level_0  index                                           abstract        date  doctype                                           headline                        id  news_desk                                          paragraph  section  subsection                                               text     type                                           dupcheck    Topic0  Topic1  Topic2  Topic3  Topic4    Topic5  Topic6  Topic7    Topic8    Topic9   Topic10  Topic11  Topic12   Topic13   Topic14  \
# ...

# %%
comb1966['text'][comb1966['Topic10']!=0]
# Out:
# 0        U.S. AIDE PREDICTS HEALTH INSURANCE WASHINGTON...
# 6        Survey Reports Some Microwave Ovens Are a Heal...
# 32       $27-Billion Paid Out in 1969 In Social Securit...
# 34       U.M.W. CHIEF ASKS PARLEY OIL SAFETY; But Inter...
# 36       ROCKEFELLER TO ASK NEW SAFEGUARDS FOR ENVIRONM...
# 37       Bal de la Neige Jan. 24 to Help Fibrosis Study...
# 47       3 Carolina Universities Join to Fight Dirty Ai...
# 48       Girl Strives to Be Pro Handler WHEN a young ow...
# 49       Browns' Coach Pessimistic About Chances Agains...
# 59       Top Lindsay Aide Expected to Leave His Staff S...
# 62       Nation is Urged to Set-Policy on Synthetic Foo...
# 66       SPEEDUP WEIGHED IN TAX COLLECTION; Treasury Dr...
# 73       DIXIE DAVIS DIES; RACKETS LAWYER; Partner of D...
# 82       Challenge by Democrats By E.W. KENWORTHY WASHI...
# 101      Insurance Accord Reached in Jersey TRENTON, Ja...
# 104      Involuntary Confinement Of Mentally Ill Oppose...
# ...

# %%
top10 = [list(comb1966['Topic47']).index(p) for p in heapq.nlargest(10, list(comb1966['Topic47']))]
list(comb1966['text'][top10])[0:9]
# Out:
# ["POLITICAL PICTURE CLEARS ON COAST; Murphy Says He Is Fit While Tunney Plans Campaign LOS ANGELES, Jan. 10--The political sediment began to settle in California this week, clearing the outlook for this year's critical Senate election. Repr Tunney to seek Repub US Sen nomination; Murphy reptdly to press campaign, may be forced out by Repub leaders who fear he would not win; speculation on Dem aspirants including Repr Brown, S I Hayakawa; Judge S Mosk drops plan to run",
#  'SENATE UNIT TOLD OF COAST HUNGER; Testimony in Los Angeles Disturbs Javits and Dole LOS ANGELES, May 8 -- A parade of witnesses in affluent Los Angeles impressed the Senate Select Committee on Nutrition and Human Needs today with stories of malnutrition, hunger and even starvation in Mexican-American barrios and black ghettos.  ',
# ...
