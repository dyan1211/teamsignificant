# %%
vis_1966 = gensimvis.prepare(lda1966, corpus, dictionary)
pyLDAvis.display(vis_1966)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4302368935975201976869279"></div>
# <script type="text/javascript">
#
# ...

# %%
vis_1971 = gensimvis.prepare(lda1971, corpus, dictionary)
pyLDAvis.display(vis_1971)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4302370536727849809353712"></div>
# <script type="text/javascript">
#
# ...

# %%
vis_1976 = gensimvis.prepare(lda1976, corpus, dictionary)
pyLDAvis.display(vis_1976)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4302360943729442880688660"></div>
# <script type="text/javascript">
#
# ...

# %%
vis_1981 = gensimvis.prepare(lda1981, corpus, dictionary)
pyLDAvis.display(vis_1981)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4302367262011683421728480"></div>
# <script type="text/javascript">
#
# ...

# %%
vis_1986 = gensimvis.prepare(lda1986, corpus, dictionary)
pyLDAvis.display(vis_1986)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4302360943738408196810243"></div>
# <script type="text/javascript">
#
# ...

# %%
vis_1991 = gensimvis.prepare(lda1991, corpus, dictionary)
pyLDAvis.display(vis_1991)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4302367261973285584267195"></div>
# <script type="text/javascript">
#
# ...

# %%
vis_1996 = gensimvis.prepare(lda1996, corpus, dictionary)
pyLDAvis.display(vis_1996)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4302367113463846754554909"></div>
# <script type="text/javascript">
#
# ...

# %%
vis_2001 = gensimvis.prepare(lda2001, corpus, dictionary)
pyLDAvis.display(vis_2001)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4302348754372642093841123"></div>
# <script type="text/javascript">
#
# ...

# %%
vis_2011 = gensimvis.prepare(lda2011, corpus, dictionary)
pyLDAvis.display(vis_2011)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4302355554761762455440431"></div>
# <script type="text/javascript">
#
# ...
